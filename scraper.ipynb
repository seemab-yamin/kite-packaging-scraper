# %%
import requests
from lxml import etree
import json
import pandas as pd
import os

# %%
PROCESSED_URLS = []


def send_request(url, save_to_file=True):
    if url in PROCESSED_URLS:
        print(f"URL {url} has already been processed.")
        return None
    PROCESSED_URLS.append(url)
    print(f"Fetching data from {url}")
    filename = url.split("/")[-2] + ".html"
    filename = "root.html" if filename == ".html" else filename
    output_dir = "kite_packaging_data"
    # if not exists, create the directory
    os.makedirs(output_dir, exist_ok=True)
    filename = os.path.join(output_dir, filename)
    # if file already exists, then read the file instead of making a request
    try:
        with open(filename, "r", encoding="utf-8") as file:
            print(f"Using cached data from {filename}")
            raw_html = file.read()
        return raw_html
    except FileNotFoundError:
        print(f"No cached data found for {filename}, making a request...")
        response = requests.get(url)
        if response.status_code != 200:
            raise ValueError(
                f"Failed to fetch data from {url}. Status code: {response.status_code}"
            )
        raw_html = response.text

        try:
            if save_to_file:
                with open(filename, "w", encoding="utf-8") as file:
                    file.write(raw_html)
                print(f"Data saved to {filename}")
        except:
            pass

    return raw_html


def fetch_categories(raw_html, root_url, xpath):
    parser = etree.HTMLParser()
    tree = etree.fromstring(raw_html, parser)
    categories = tree.xpath(xpath)
    return [root_url + cat for cat in categories]

# %%
def parse_product_variants(tree):
    parser = etree.HTMLParser()
    # fetch categories
    categories = " > ".join(tree.xpath('//ul[@class="breadcrumb-menu"]/li/*/text()'))

    # get all image URLs from the carousel
    image_urls = [
        ie.get("data-large-src") if ie.get("data-large-src") else ie.get("data-src")
        for ie in tree.xpath('//*[@id="P-Carousel"]//img')
    ]
    # bullet text
    custom_bullet_text = "\n".join(
        [
            item
            for item in tree.xpath('//div[@class="custom-bullet"]//text()')
            if item.strip()
        ]
    )

    # about section
    about_section = "\n".join(
        [
            item.replace("\xa0", "")
            for item in tree.xpath(
                '//div[@id="details-tab"]/div[@class="catpagemaintext"]//text()'
            )
            if item.strip()
        ]
    )

    # prepare the base data structure
    base_data = {
        "categories": categories,
        "image_urls": image_urls,
        "custom_bullet_text": custom_bullet_text,
        "about_section": about_section,
    }

    # get script tag element with xpath: //script[@id="ang-data-source"]
    script_tag = tree.xpath('//script[@id="ang-data-source"]')
    if not script_tag:
        raise ValueError("No script tag with id 'ang-data-source' found in the HTML.")
    script_tag = "{" + script_tag[0].text.split("{", 1)[-1].rsplit("}", 1)[0] + "}"
    # extract the JSON data from the script tag
    # parse the JSON data
    product_data = json.loads(script_tag)

    products = product_data.get("productTables")[0].get("products")

    master_list = []
    for prod in products:
        # parse notes as HTML and extract text
        notes = prod.get("notes", "")
        if notes:
            notes = etree.fromstring(notes, parser)
            notes = "\n".join(
                [item.strip() for item in notes.xpath("//text()") if item.strip()]
            )
        else:
            notes = ""

        modal_images = [
            item.get("location")
            for mi in prod.get("modalImages", [])
            for item in mi.get("items")
            if item.get("typeAnnotation") == "L"
        ]

        internal_dimensions = " x ".join(
            map(str, prod.get("internalDimensions", {}).values())
        )

        videos = prod.get("videos", [])
        images = [
            item.get("location")
            for mi in prod.get("images", [])
            for item in mi.get("items")
            if item.get("typeAnnotation") == "L"
        ]
        description = prod.get("description", "")
        basket_description = prod.get("basketDescription", "")

        # specifications
        specs_dict = {
            item.get("description"): item.get("value")
            for item in prod.get("specifications")
            if item.get("value") != "None"
        }

        unit_per_pallet = prod.get("palletSize")
        unit_per_pack = prod.get("packSize")

        price_per_pack = {
            f"{item.get('min')}-{item.get('max')} Packs": item.get("price")
            for item in prod.get("packBreaks")
        }
        price_per_pallet = {
            f"{item.get('min')}-{item.get('max')} Packs": item.get("price")
            for item in prod.get("palletBreaks")
        }
        master_list.append(
            {
                **base_data,
                **specs_dict,
                "notes": notes,
                "modal_images": modal_images,
                "internal_dimensions": internal_dimensions,
                "videos": videos,
                "images": images,
                "description": description,
                "basket_description": basket_description,
                "unit_per_pallet": unit_per_pallet,
                "unit_per_pack": unit_per_pack,
                "price_per_pack": price_per_pack,
                "price_per_pallet": price_per_pallet,
            }
        )
    return pd.DataFrame(master_list)

# %%
# get categories
root_url = "https://www.kitepackaging.co.uk"
raw_html = send_request(root_url)
categories = fetch_categories(raw_html, root_url, xpath="//div[@class='list-group']/a/@href")

master_sub_cat = []
for cat_url in categories:
    print(f"Processing category: {cat_url}")
    raw_html = send_request(cat_url)
    if raw_html:
        sub_cat_urls = fetch_categories(raw_html, root_url, xpath="//a[@class='list-group-item dropme-left ']/@href")
        master_sub_cat.extend(sub_cat_urls)
# Out:
# Fetching data from https://www.kitepackaging.co.uk
# Using cached data from kite_packaging_data/root.html
# Processing category: https://www.kitepackaging.co.uk/scp/boxes/cardboard-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/cardboard-boxes/
# Using cached data from kite_packaging_data/cardboard-boxes.html
# Processing category: https://www.kitepackaging.co.uk/mcp/pallet-wrap/
# Fetching data from https://www.kitepackaging.co.uk/mcp/pallet-wrap/
# Using cached data from kite_packaging_data/pallet-wrap.html
# Processing category: https://www.kitepackaging.co.uk/mcp/tapes/
# Fetching data from https://www.kitepackaging.co.uk/mcp/tapes/
# Using cached data from kite_packaging_data/tapes.html
# Processing category: https://www.kitepackaging.co.uk/mcp/bubble-wrap/
# Fetching data from https://www.kitepackaging.co.uk/mcp/bubble-wrap/
# Using cached data from kite_packaging_data/bubble-wrap.html
# Processing category: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/voidfill-and-loosefill/
# Fetching data from https://www.kitepackaging.co.uk/scp/protection-and-wrapping/voidfill-and-loosefill/
# Using cached data from kite_packaging_data/voidfill-and-loosefill.html
# Processing category: https://www.kitepackaging.co.uk/mcp/cardboard-sheets-and-rolls/
# Fetching data from https://www.kitepackaging.co.uk/mcp/cardboard-sheets-and-rolls/
# Using cached data from kite_packaging_data/cardboard-sheets-and-rolls.html
# Processing category: https://www.kitepackaging.co.uk/mcp/bags/
# Fetching data from https://www.kitepackaging.co.uk/mcp/bags/
# Using cached data from kite_packaging_data/bags.html
# Processing category: https://www.kitepackaging.co.uk/mcp/polythene-rolls-and-tubing/
# Fetching data from https://www.kitepackaging.co.uk/mcp/polythene-rolls-and-tubing/
# Using cached data from kite_packaging_data/polythene-rolls-and-tubing.html
# Processing category: https://www.kitepackaging.co.uk/mcp/labels/
# Fetching data from https://www.kitepackaging.co.uk/mcp/labels/
# Using cached data from kite_packaging_data/labels.html
# Processing category: https://www.kitepackaging.co.uk/mcp/postal-products/
# Fetching data from https://www.kitepackaging.co.uk/mcp/postal-products/
# Using cached data from kite_packaging_data/postal-products.html
# Processing category: https://www.kitepackaging.co.uk/mcp/food-packaging/
# Fetching data from https://www.kitepackaging.co.uk/mcp/food-packaging/
# Using cached data from kite_packaging_data/food-packaging.html
# Processing category: https://www.kitepackaging.co.uk/mcp/papers/
# Fetching data from https://www.kitepackaging.co.uk/mcp/papers/
# Using cached data from kite_packaging_data/papers.html
# Processing category: https://www.kitepackaging.co.uk/mcp/layer-pads-and-sheets/
# Fetching data from https://www.kitepackaging.co.uk/mcp/layer-pads-and-sheets/
# Using cached data from kite_packaging_data/layer-pads-and-sheets.html
# Processing category: https://www.kitepackaging.co.uk/mcp/pallets-and-pallet-boxes/
# Fetching data from https://www.kitepackaging.co.uk/mcp/pallets-and-pallet-boxes/
# Using cached data from kite_packaging_data/pallets-and-pallet-boxes.html
# Processing category: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/foam-protection/
# Fetching data from https://www.kitepackaging.co.uk/scp/protection-and-wrapping/foam-protection/
# Using cached data from kite_packaging_data/foam-protection.html
# Processing category: https://www.kitepackaging.co.uk/mcp/heat-shrink-and-vacuum-packaging/
# Fetching data from https://www.kitepackaging.co.uk/mcp/heat-shrink-and-vacuum-packaging/
# Using cached data from kite_packaging_data/heat-shrink-and-vacuum-packaging.html
# Processing category: https://www.kitepackaging.co.uk/mcp/strapping-and-ties/
# Fetching data from https://www.kitepackaging.co.uk/mcp/strapping-and-ties/
# Using cached data from kite_packaging_data/strapping-and-ties.html
# Processing category: https://www.kitepackaging.co.uk/mcp/chilled-packaging/
# Fetching data from https://www.kitepackaging.co.uk/mcp/chilled-packaging/
# Using cached data from kite_packaging_data/chilled-packaging.html
# Processing category: https://www.kitepackaging.co.uk/mcp/gift-packaging/
# Fetching data from https://www.kitepackaging.co.uk/mcp/gift-packaging/
# Using cached data from kite_packaging_data/gift-packaging.html
# Processing category: https://www.kitepackaging.co.uk/mcp/desiccants-and-vci/
# Fetching data from https://www.kitepackaging.co.uk/mcp/desiccants-and-vci/
# Using cached data from kite_packaging_data/desiccants-and-vci.html
# Processing category: https://www.kitepackaging.co.uk/mcp/packroom-equipment/
# Fetching data from https://www.kitepackaging.co.uk/mcp/packroom-equipment/
# Using cached data from kite_packaging_data/packroom-equipment.html
# Processing category: https://www.kitepackaging.co.uk/mcp/staples-and-glue/
# Fetching data from https://www.kitepackaging.co.uk/mcp/staples-and-glue/
# Using cached data from kite_packaging_data/staples-and-glue.html
# Processing category: https://www.kitepackaging.co.uk/mcp/environmental-products/
# Fetching data from https://www.kitepackaging.co.uk/mcp/environmental-products/
# Using cached data from kite_packaging_data/environmental-products.html

# %%
i = 0
master_prod_df = pd.DataFrame()
while i < len(master_sub_cat):
    print(f"Processing sub category {i + 1}/{len(master_sub_cat)}: {master_sub_cat[i]}")
    url = master_sub_cat[i]
    if "custom" in url:
        print(f"Skipping custom: {url}")
        i += 1
        continue
    sub_cat_raw_html = send_request(url)
    if not sub_cat_raw_html:
        i += 1
        print(f"Failed to fetch data for {url}, skipping...")
        continue

    # create etree object to use xpath
    parser = etree.HTMLParser()
    tree = etree.fromstring(sub_cat_raw_html, parser)

    sub_sub_urls = tree.xpath(
        ('//div[@class="product-group-container"]/div[@class="tile-container"]/a/@href')
    )

    if sub_sub_urls:
        # append each sub-sub category
        master_sub_cat.extend([root_url + url for url in sub_sub_urls])
    else:
        try:
            prod_df = parse_product_variants(tree)
            prod_df["url"] = url
            master_prod_df = pd.concat([master_prod_df, prod_df], ignore_index=True)
        except ValueError as e:
            print(f"Error processing {url}: {e}")
    i += 1
# Out:
# Processing sub category 1/218: https://www.kitepackaging.co.uk/scp/boxes/standard-cardboard-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/standard-cardboard-boxes/
# Using cached data from kite_packaging_data/standard-cardboard-boxes.html
# Processing sub category 2/218: https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/double-wall-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/double-wall-boxes/
# Using cached data from kite_packaging_data/double-wall-boxes.html
# Processing sub category 3/218: https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/enviro-box/
# Fetching data from https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/enviro-box/
# Using cached data from kite_packaging_data/enviro-box.html
# Processing sub category 4/218: https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/extra-heavy-duty-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/extra-heavy-duty-boxes/
# Using cached data from kite_packaging_data/extra-heavy-duty-boxes.html
# Processing sub category 5/218: https://www.kitepackaging.co.uk/scp/boxes/bdcm-cardboard-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/bdcm-cardboard-boxes/
# Using cached data from kite_packaging_data/bdcm-cardboard-boxes.html
# Processing sub category 6/218: https://www.kitepackaging.co.uk/mcp/postal-boxes/
# Fetching data from https://www.kitepackaging.co.uk/mcp/postal-boxes/
# Using cached data from kite_packaging_data/postal-boxes.html
# Processing sub category 7/190: https://www.kitepackaging.co.uk/scp/polythene-bags/garment-bags-and-covers/
# Fetching data from https://www.kitepackaging.co.uk/scp/polythene-bags/garment-bags-and-covers/
# Using cached data from kite_packaging_data/garment-bags-and-covers.html
# Processing sub category 8/190: https://www.kitepackaging.co.uk/mcp/refuse-and-rubble-sacks/
# Fetching data from https://www.kitepackaging.co.uk/mcp/refuse-and-rubble-sacks/
# Using cached data from kite_packaging_data/refuse-and-rubble-sacks.html
# Processing sub category 9/195: https://www.kitepackaging.co.uk/mcp/refuse-and-rubble-sacks/
# URL https://www.kitepackaging.co.uk/mcp/refuse-and-rubble-sacks/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/refuse-and-rubble-sacks/, skipping...
# Processing sub category 10/195: https://www.kitepackaging.co.uk/scp/labels/integrated-labels/
# Fetching data from https://www.kitepackaging.co.uk/scp/labels/integrated-labels/
# Using cached data from kite_packaging_data/integrated-labels.html
# Processing sub category 11/195: https://www.kitepackaging.co.uk/scp/chilled-packaging/corrugated-insulated-box-liners/
# Fetching data from https://www.kitepackaging.co.uk/scp/chilled-packaging/corrugated-insulated-box-liners/
# Using cached data from kite_packaging_data/corrugated-insulated-box-liners.html
# Processing sub category 12/195: https://www.kitepackaging.co.uk/scp/pallets-and-pallet-boxes/do-not-stack-cones/
# Fetching data from https://www.kitepackaging.co.uk/scp/pallets-and-pallet-boxes/do-not-stack-cones/
# Using cached data from kite_packaging_data/do-not-stack-cones.html
# Processing sub category 13/195: https://www.kitepackaging.co.uk/scp/postal-boxes/cd-dvd-lp-packaging/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-boxes/cd-dvd-lp-packaging/
# Using cached data from kite_packaging_data/cd-dvd-lp-packaging.html
# Processing sub category 14/195: https://www.kitepackaging.co.uk/scp/labels/paper-tags/
# Fetching data from https://www.kitepackaging.co.uk/scp/labels/paper-tags/
# Using cached data from kite_packaging_data/paper-tags.html
# Processing sub category 15/195: https://www.kitepackaging.co.uk/scp/boxes/bdcm-cardboard-boxes/
# URL https://www.kitepackaging.co.uk/scp/boxes/bdcm-cardboard-boxes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/boxes/bdcm-cardboard-boxes/, skipping...
# Processing sub category 16/195: https://www.kitepackaging.co.uk/mcp/strapping/
# Fetching data from https://www.kitepackaging.co.uk/mcp/strapping/
# Using cached data from kite_packaging_data/strapping.html
# Processing sub category 17/206: https://www.kitepackaging.co.uk/scp/pallet-wrap/5x5-dispenser/
# Fetching data from https://www.kitepackaging.co.uk/scp/pallet-wrap/5x5-dispenser/
# Using cached data from kite_packaging_data/5x5-dispenser.html
# Processing sub category 18/206: https://www.kitepackaging.co.uk/scp/pallet-wrap/custom-stretch/
# Skipping custom: https://www.kitepackaging.co.uk/scp/pallet-wrap/custom-stretch/
# Processing sub category 19/206: https://www.kitepackaging.co.uk/scp/papers/hivewrap/
# Fetching data from https://www.kitepackaging.co.uk/scp/papers/hivewrap/
# Using cached data from kite_packaging_data/hivewrap.html
# Processing sub category 20/206: https://www.kitepackaging.co.uk/scp/furniture-bags/furniture-protection/
# Fetching data from https://www.kitepackaging.co.uk/scp/furniture-bags/furniture-protection/
# Using cached data from kite_packaging_data/furniture-protection.html
# Processing sub category 21/206: https://www.kitepackaging.co.uk/scp/postal-products/cardboard-envelopes-and-mailers/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-products/cardboard-envelopes-and-mailers/
# Using cached data from kite_packaging_data/cardboard-envelopes-and-mailers.html
# Processing sub category 22/206: https://www.kitepackaging.co.uk/scp/papers/shredded-paper/
# Fetching data from https://www.kitepackaging.co.uk/scp/papers/shredded-paper/
# Using cached data from kite_packaging_data/shredded-paper.html
# Processing sub category 23/206: https://www.kitepackaging.co.uk/scp/heat-shrink-wrap/continuous-tubing-on-a-roll/
# Fetching data from https://www.kitepackaging.co.uk/scp/heat-shrink-wrap/continuous-tubing-on-a-roll/
# Using cached data from kite_packaging_data/continuous-tubing-on-a-roll.html
# Processing sub category 24/206: https://www.kitepackaging.co.uk/scp/plastics/refuse-sacks/
# Fetching data from https://www.kitepackaging.co.uk/scp/plastics/refuse-sacks/
# Using cached data from kite_packaging_data/refuse-sacks.html
# Processing sub category 25/206: https://www.kitepackaging.co.uk/scp/strapping-and-ties/pallet-probe/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping-and-ties/pallet-probe/
# Using cached data from kite_packaging_data/pallet-probe.html
# Processing sub category 26/206: https://www.kitepackaging.co.uk/scp/bespokepackaging/bagging-machines/
# Fetching data from https://www.kitepackaging.co.uk/scp/bespokepackaging/bagging-machines/
# Using cached data from kite_packaging_data/bagging-machines.html
# Processing sub category 27/206: https://www.kitepackaging.co.uk/scp/tapes/crossweave-tape/
# Fetching data from https://www.kitepackaging.co.uk/scp/tapes/crossweave-tape/
# Using cached data from kite_packaging_data/crossweave-tape.html
# Processing sub category 28/206: https://www.kitepackaging.co.uk/scp/polythene-bags/clear-polythene-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/polythene-bags/clear-polythene-bags/
# Using cached data from kite_packaging_data/clear-polythene-bags.html
# Processing sub category 29/211: https://www.kitepackaging.co.uk/scp/tapes/crossweave-tape/
# URL https://www.kitepackaging.co.uk/scp/tapes/crossweave-tape/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/tapes/crossweave-tape/, skipping...
# Processing sub category 30/211: https://www.kitepackaging.co.uk/scp/polythene-bags/clear-polythene-bags/
# URL https://www.kitepackaging.co.uk/scp/polythene-bags/clear-polythene-bags/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/polythene-bags/clear-polythene-bags/, skipping...
# Processing sub category 31/211: https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-film-dispensers/
# Fetching data from https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-film-dispensers/
# Using cached data from kite_packaging_data/stretch-film-dispensers.html
# Processing sub category 32/211: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/silica-gel/
# Fetching data from https://www.kitepackaging.co.uk/scp/protection-and-wrapping/silica-gel/
# Using cached data from kite_packaging_data/silica-gel.html
# Processing sub category 33/211: https://www.kitepackaging.co.uk/mcp/air-bags-and-cushions/
# Fetching data from https://www.kitepackaging.co.uk/mcp/air-bags-and-cushions/
# Using cached data from kite_packaging_data/air-bags-and-cushions.html
# Processing sub category 34/215: https://www.kitepackaging.co.uk/scp/bags/carrier-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/bags/carrier-bags/
# Using cached data from kite_packaging_data/carrier-bags.html
# Processing sub category 35/216: https://www.kitepackaging.co.uk/scp/tapes/self-adhesive-paper-kraft-tape/
# Fetching data from https://www.kitepackaging.co.uk/scp/tapes/self-adhesive-paper-kraft-tape/
# Using cached data from kite_packaging_data/self-adhesive-paper-kraft-tape.html
# Processing sub category 36/216: https://www.kitepackaging.co.uk/scp/postal-boxes/capacity-book-mailers/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-boxes/capacity-book-mailers/
# Using cached data from kite_packaging_data/capacity-book-mailers.html
# Processing sub category 37/216: https://www.kitepackaging.co.uk/mcp/furniture-bags/
# Fetching data from https://www.kitepackaging.co.uk/mcp/furniture-bags/
# Using cached data from kite_packaging_data/furniture-bags.html
# Processing sub category 38/219: https://www.kitepackaging.co.uk/scp/food-packaging/pizza-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/food-packaging/pizza-boxes/
# Using cached data from kite_packaging_data/pizza-boxes.html
# Processing sub category 39/219: https://www.kitepackaging.co.uk/scp/polythene-bags/perforated-poly-bags-on-a-roll/
# Fetching data from https://www.kitepackaging.co.uk/scp/polythene-bags/perforated-poly-bags-on-a-roll/
# Using cached data from kite_packaging_data/perforated-poly-bags-on-a-roll.html
# Processing sub category 40/219: https://www.kitepackaging.co.uk/scp/tapes/48mm-packaging-tape/
# Fetching data from https://www.kitepackaging.co.uk/scp/tapes/48mm-packaging-tape/
# Using cached data from kite_packaging_data/48mm-packaging-tape.html
# Processing sub category 41/219: https://www.kitepackaging.co.uk/printedstandard/printed-envelopes
# Fetching data from https://www.kitepackaging.co.uk/printedstandard/printed-envelopes
# Using cached data from kite_packaging_data/printedstandard.html
# Processing sub category 42/219: https://www.kitepackaging.co.uk/scp/postal-boxes/white-postal-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-boxes/white-postal-boxes/
# Using cached data from kite_packaging_data/white-postal-boxes.html
# Processing sub category 43/219: https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-wrapping-machine/
# Fetching data from https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-wrapping-machine/
# Using cached data from kite_packaging_data/stretch-wrapping-machine.html
# Processing sub category 44/219: https://www.kitepackaging.co.uk/scp/strapping/strapping-edge-protectors/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping/strapping-edge-protectors/
# Using cached data from kite_packaging_data/strapping-edge-protectors.html
# Processing sub category 45/219: https://www.kitepackaging.co.uk/scp/foam/self-adhesive-foam-blocks/
# Fetching data from https://www.kitepackaging.co.uk/scp/foam/self-adhesive-foam-blocks/
# Using cached data from kite_packaging_data/self-adhesive-foam-blocks.html
# Processing sub category 46/219: https://www.kitepackaging.co.uk/scp/packroom-equipment/void-fill-equipment/
# Fetching data from https://www.kitepackaging.co.uk/scp/packroom-equipment/void-fill-equipment/
# Using cached data from kite_packaging_data/void-fill-equipment.html
# Processing sub category 47/219: https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/double-wall-boxes/
# URL https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/double-wall-boxes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/double-wall-boxes/, skipping...
# Processing sub category 48/219: https://www.kitepackaging.co.uk/scp/plastics/rubble-sacks/
# Fetching data from https://www.kitepackaging.co.uk/scp/plastics/rubble-sacks/
# Using cached data from kite_packaging_data/rubble-sacks.html
# Processing sub category 49/219: https://www.kitepackaging.co.uk/scp/food-packaging/fish-and-chip-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/food-packaging/fish-and-chip-boxes/
# Using cached data from kite_packaging_data/fish-and-chip-boxes.html
# Processing sub category 50/219: https://www.kitepackaging.co.uk/scp/strapping/paper-strapping-and-film-strapping/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping/paper-strapping-and-film-strapping/
# Using cached data from kite_packaging_data/paper-strapping-and-film-strapping.html
# Processing sub category 51/219: https://www.kitepackaging.co.uk/scp/gift-packaging/shredded-tissue-paper/
# Fetching data from https://www.kitepackaging.co.uk/scp/gift-packaging/shredded-tissue-paper/
# Using cached data from kite_packaging_data/shredded-tissue-paper.html
# Processing sub category 52/219: https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-trucks/
# Fetching data from https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-trucks/
# Using cached data from kite_packaging_data/pallet-trucks.html
# Processing sub category 53/219: https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/extra-heavy-duty-boxes/
# URL https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/extra-heavy-duty-boxes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/extra-heavy-duty-boxes/, skipping...
# Processing sub category 54/219: https://www.kitepackaging.co.uk/scp/bubble-wrap/anti-static-pink-bubble-wrap/
# Fetching data from https://www.kitepackaging.co.uk/scp/bubble-wrap/anti-static-pink-bubble-wrap/
# Using cached data from kite_packaging_data/anti-static-pink-bubble-wrap.html
# Processing sub category 55/219: https://www.kitepackaging.co.uk/scp/papers/news-offcuts-filler-paper/
# Fetching data from https://www.kitepackaging.co.uk/scp/papers/news-offcuts-filler-paper/
# Using cached data from kite_packaging_data/news-offcuts-filler-paper.html
# Processing sub category 56/219: https://www.kitepackaging.co.uk/scp/bubble-wrap/paper-bubble-dispenser-box/
# Fetching data from https://www.kitepackaging.co.uk/scp/bubble-wrap/paper-bubble-dispenser-box/
# Using cached data from kite_packaging_data/paper-bubble-dispenser-box.html
# Processing sub category 57/219: https://www.kitepackaging.co.uk/scp/food-packaging/kraft-takeaway-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/food-packaging/kraft-takeaway-boxes/
# Using cached data from kite_packaging_data/kraft-takeaway-boxes.html
# Processing sub category 58/219: https://www.kitepackaging.co.uk/scp/postal-envelopes/bubble-lined-padded-envelopes/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-envelopes/bubble-lined-padded-envelopes/
# Using cached data from kite_packaging_data/bubble-lined-padded-envelopes.html
# Processing sub category 59/226: https://www.kitepackaging.co.uk/scp/postal-boxes/foam-lined-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-boxes/foam-lined-boxes/
# Using cached data from kite_packaging_data/foam-lined-boxes.html
# Processing sub category 60/228: https://www.kitepackaging.co.uk/scp/postal-boxes/foam-lined-boxes/
# URL https://www.kitepackaging.co.uk/scp/postal-boxes/foam-lined-boxes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/postal-boxes/foam-lined-boxes/, skipping...
# Processing sub category 61/228: https://www.kitepackaging.co.uk/scp/sealing-and-security/document-enclosed-wallets/
# Fetching data from https://www.kitepackaging.co.uk/scp/sealing-and-security/document-enclosed-wallets/
# Using cached data from kite_packaging_data/document-enclosed-wallets.html
# Processing sub category 62/228: https://www.kitepackaging.co.uk/mcp/heat-sealers/
# Fetching data from https://www.kitepackaging.co.uk/mcp/heat-sealers/
# Using cached data from kite_packaging_data/heat-sealers.html
# Processing sub category 63/236: https://www.kitepackaging.co.uk/mcp/heat-sealers/
# URL https://www.kitepackaging.co.uk/mcp/heat-sealers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/heat-sealers/, skipping...
# Processing sub category 64/236: https://www.kitepackaging.co.uk/scp/gift-packaging/shredpak-2mm-shredded-paper/
# Fetching data from https://www.kitepackaging.co.uk/scp/gift-packaging/shredpak-2mm-shredded-paper/
# Using cached data from kite_packaging_data/shredpak-2mm-shredded-paper.html
# Processing sub category 65/236: https://www.kitepackaging.co.uk/scp/boxes/pallet-boxes-build-a-box/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/pallet-boxes-build-a-box/
# Using cached data from kite_packaging_data/pallet-boxes-build-a-box.html
# Processing sub category 66/236: https://www.kitepackaging.co.uk/scp/postal-envelopes/kite-enviro-mailers/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-envelopes/kite-enviro-mailers/
# Using cached data from kite_packaging_data/kite-enviro-mailers.html
# Processing sub category 67/236: https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/enviro-box/
# URL https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/enviro-box/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/enviro-box/, skipping...
# Processing sub category 68/236: https://www.kitepackaging.co.uk/scp/boxes/wax-lined-boxes-for-food/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/wax-lined-boxes-for-food/
# Using cached data from kite_packaging_data/wax-lined-boxes-for-food.html
# Processing sub category 69/236: https://www.kitepackaging.co.uk/scp/furniture-bags/furniture-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/furniture-bags/furniture-bags/
# Using cached data from kite_packaging_data/furniture-bags.html
# Processing sub category 70/236: https://www.kitepackaging.co.uk/mcp/paper-bags/
# Fetching data from https://www.kitepackaging.co.uk/mcp/paper-bags/
# Using cached data from kite_packaging_data/paper-bags.html
# Processing sub category 71/239: https://www.kitepackaging.co.uk/scp/furniture-bags/furniture-bags/
# URL https://www.kitepackaging.co.uk/scp/furniture-bags/furniture-bags/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/furniture-bags/furniture-bags/, skipping...
# Processing sub category 72/239: https://www.kitepackaging.co.uk/mcp/paper-bags/
# URL https://www.kitepackaging.co.uk/mcp/paper-bags/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/paper-bags/, skipping...
# Processing sub category 73/239: https://www.kitepackaging.co.uk/mcp/removals-packaging/
# Fetching data from https://www.kitepackaging.co.uk/mcp/removals-packaging/
# Using cached data from kite_packaging_data/removals-packaging.html
# Processing sub category 74/242: https://www.kitepackaging.co.uk/mcp/removals-packaging/
# URL https://www.kitepackaging.co.uk/mcp/removals-packaging/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/removals-packaging/, skipping...
# Processing sub category 75/242: https://www.kitepackaging.co.uk/scp/plastics/polythene-rolls/
# Fetching data from https://www.kitepackaging.co.uk/scp/plastics/polythene-rolls/
# Using cached data from kite_packaging_data/polythene-rolls.html
# Processing sub category 76/242: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/foam-rolls/
# Fetching data from https://www.kitepackaging.co.uk/scp/protection-and-wrapping/foam-rolls/
# Using cached data from kite_packaging_data/foam-rolls.html
# Processing sub category 77/242: https://www.kitepackaging.co.uk/scp/bubble-wrap/paper-bubble-wrap/
# Fetching data from https://www.kitepackaging.co.uk/scp/bubble-wrap/paper-bubble-wrap/
# Using cached data from kite_packaging_data/paper-bubble-wrap.html
# Processing sub category 78/242: https://www.kitepackaging.co.uk/scp/environmental-products/replace/
# Fetching data from https://www.kitepackaging.co.uk/scp/environmental-products/replace/
# Using cached data from kite_packaging_data/replace.html
# Processing sub category 79/246: https://www.kitepackaging.co.uk/scp/environmental-products/replace/
# URL https://www.kitepackaging.co.uk/scp/environmental-products/replace/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/environmental-products/replace/, skipping...
# Processing sub category 80/246: https://www.kitepackaging.co.uk/mcp/cable-ties/
# Fetching data from https://www.kitepackaging.co.uk/mcp/cable-ties/
# Using cached data from kite_packaging_data/cable-ties.html
# Processing sub category 81/248: https://www.kitepackaging.co.uk/mcp/cable-ties/
# URL https://www.kitepackaging.co.uk/mcp/cable-ties/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/cable-ties/, skipping...
# Processing sub category 82/248: https://www.kitepackaging.co.uk/mcp/pallets-and-export-boxes/
# Fetching data from https://www.kitepackaging.co.uk/mcp/pallets-and-export-boxes/
# Using cached data from kite_packaging_data/pallets-and-export-boxes.html
# Processing sub category 83/249: https://www.kitepackaging.co.uk/scp/postal-products/cardboard-postal-tubes/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-products/cardboard-postal-tubes/
# Using cached data from kite_packaging_data/cardboard-postal-tubes.html
# Processing sub category 84/249: https://www.kitepackaging.co.uk/scp/labels/thermal-labels/
# Fetching data from https://www.kitepackaging.co.uk/scp/labels/thermal-labels/
# Using cached data from kite_packaging_data/thermal-labels.html
# Processing sub category 85/249: https://www.kitepackaging.co.uk/scp/boxes/white-cardboard-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/white-cardboard-boxes/
# Using cached data from kite_packaging_data/white-cardboard-boxes.html
# Processing sub category 86/249: https://www.kitepackaging.co.uk/mcp/heat-shrink-wrap/
# Fetching data from https://www.kitepackaging.co.uk/mcp/heat-shrink-wrap/
# Using cached data from kite_packaging_data/heat-shrink-wrap.html
# Processing sub category 87/254: https://www.kitepackaging.co.uk/scp/boxes/white-cardboard-boxes/
# URL https://www.kitepackaging.co.uk/scp/boxes/white-cardboard-boxes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/boxes/white-cardboard-boxes/, skipping...
# Processing sub category 88/254: https://www.kitepackaging.co.uk/mcp/heat-shrink-wrap/
# URL https://www.kitepackaging.co.uk/mcp/heat-shrink-wrap/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/heat-shrink-wrap/, skipping...
# Processing sub category 89/254: https://www.kitepackaging.co.uk/scp/polythene-bags/blue-tint-gusseted-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/polythene-bags/blue-tint-gusseted-bags/
# Using cached data from kite_packaging_data/blue-tint-gusseted-bags.html
# Processing sub category 90/254: https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-wrap-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-wrap-bags/
# Using cached data from kite_packaging_data/bubble-wrap-bags.html
# Processing sub category 91/256: https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-wrap-bags/
# URL https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-wrap-bags/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-wrap-bags/, skipping...
# Processing sub category 92/256: https://www.kitepackaging.co.uk/scp/clear-gift-and-card-bags/greeting-card-bags-with-resealable-strip/
# Fetching data from https://www.kitepackaging.co.uk/scp/clear-gift-and-card-bags/greeting-card-bags-with-resealable-strip/
# Using cached data from kite_packaging_data/greeting-card-bags-with-resealable-strip.html
# Error processing https://www.kitepackaging.co.uk/scp/clear-gift-and-card-bags/greeting-card-bags-with-resealable-strip/: No script tag with id 'ang-data-source' found in the HTML.
# Processing sub category 93/256: https://www.kitepackaging.co.uk/mcp/heat-shrink-machines-and-equipment/
# Fetching data from https://www.kitepackaging.co.uk/mcp/heat-shrink-machines-and-equipment/
# Using cached data from kite_packaging_data/heat-shrink-machines-and-equipment.html
# Processing sub category 94/258: https://www.kitepackaging.co.uk/mcp/heat-shrink-machines-and-equipment/
# URL https://www.kitepackaging.co.uk/mcp/heat-shrink-machines-and-equipment/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/heat-shrink-machines-and-equipment/, skipping...
# Processing sub category 95/258: https://www.kitepackaging.co.uk/scp/boxes/picture-frame-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/picture-frame-boxes/
# Using cached data from kite_packaging_data/picture-frame-boxes.html
# Processing sub category 96/258: https://www.kitepackaging.co.uk/scp/strapping/polyester-strapping/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping/polyester-strapping/
# Using cached data from kite_packaging_data/polyester-strapping.html
# Processing sub category 97/262: https://www.kitepackaging.co.uk/scp/boxes/picture-frame-boxes/
# URL https://www.kitepackaging.co.uk/scp/boxes/picture-frame-boxes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/boxes/picture-frame-boxes/, skipping...
# Processing sub category 98/262: https://www.kitepackaging.co.uk/scp/strapping/polyester-strapping/
# URL https://www.kitepackaging.co.uk/scp/strapping/polyester-strapping/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/strapping/polyester-strapping/, skipping...
# Processing sub category 99/262: https://www.kitepackaging.co.uk/scp/postal-envelopes/jiffy-airkraft-bubble-lined-envelopes/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-envelopes/jiffy-airkraft-bubble-lined-envelopes/
# Using cached data from kite_packaging_data/jiffy-airkraft-bubble-lined-envelopes.html
# Processing sub category 100/262: https://www.kitepackaging.co.uk/mcp/custom-tape/
# Skipping custom: https://www.kitepackaging.co.uk/mcp/custom-tape/
# Processing sub category 101/262: https://www.kitepackaging.co.uk/scp/clear-gift-and-card-bags/clear-florist-wrap/
# Fetching data from https://www.kitepackaging.co.uk/scp/clear-gift-and-card-bags/clear-florist-wrap/
# Using cached data from kite_packaging_data/clear-florist-wrap.html
# Processing sub category 102/262: https://www.kitepackaging.co.uk/scp/labels/circle-labels/
# Fetching data from https://www.kitepackaging.co.uk/scp/labels/circle-labels/
# Using cached data from kite_packaging_data/circle-labels.html
# Processing sub category 103/262: https://www.kitepackaging.co.uk/scp/strapping/bale-strapping/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping/bale-strapping/
# Using cached data from kite_packaging_data/bale-strapping.html
# Processing sub category 104/262: https://www.kitepackaging.co.uk/scp/tapes/25mm-packaging-tape/
# Fetching data from https://www.kitepackaging.co.uk/scp/tapes/25mm-packaging-tape/
# Using cached data from kite_packaging_data/25mm-packaging-tape.html
# Processing sub category 105/262: https://www.kitepackaging.co.uk/mcp/boxes-for-bottles/
# Fetching data from https://www.kitepackaging.co.uk/mcp/boxes-for-bottles/
# Using cached data from kite_packaging_data/boxes-for-bottles.html
# Processing sub category 106/264: https://www.kitepackaging.co.uk/scp/tapes/tape-dispensers/
# Fetching data from https://www.kitepackaging.co.uk/scp/tapes/tape-dispensers/
# Using cached data from kite_packaging_data/tape-dispensers.html
# Processing sub category 107/266: https://www.kitepackaging.co.uk/scp/tapes/tape-dispensers/
# URL https://www.kitepackaging.co.uk/scp/tapes/tape-dispensers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/tapes/tape-dispensers/, skipping...
# Processing sub category 108/266: https://www.kitepackaging.co.uk/scp/plastics/fibc-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/plastics/fibc-bags/
# Using cached data from kite_packaging_data/fibc-bags.html
# Processing sub category 109/266: https://www.kitepackaging.co.uk/scp/boxes/cardboard-delivery-trays/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/cardboard-delivery-trays/
# Using cached data from kite_packaging_data/cardboard-delivery-trays.html
# Processing sub category 110/266: https://www.kitepackaging.co.uk/mcp/envelopes/
# Fetching data from https://www.kitepackaging.co.uk/mcp/envelopes/
# Using cached data from kite_packaging_data/envelopes.html
# Processing sub category 111/268: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/triangular-postal-tubes/
# Fetching data from https://www.kitepackaging.co.uk/scp/protection-and-wrapping/triangular-postal-tubes/
# Using cached data from kite_packaging_data/triangular-postal-tubes.html
# Processing sub category 112/268: https://www.kitepackaging.co.uk/scp/postal-boxes/book-wrap-cardboard-mailers/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-boxes/book-wrap-cardboard-mailers/
# Using cached data from kite_packaging_data/book-wrap-cardboard-mailers.html
# Processing sub category 113/268: https://www.kitepackaging.co.uk/mcp/bubble-wrap/
# URL https://www.kitepackaging.co.uk/mcp/bubble-wrap/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/bubble-wrap/, skipping...
# Processing sub category 114/268: https://www.kitepackaging.co.uk/scp/tapes/coloured-packaging-tape/
# Fetching data from https://www.kitepackaging.co.uk/scp/tapes/coloured-packaging-tape/
# Using cached data from kite_packaging_data/coloured-packaging-tape.html
# Processing sub category 115/268: https://www.kitepackaging.co.uk/scp/heat-sealers/heavy-duty-heat-sealer-accessories/
# Fetching data from https://www.kitepackaging.co.uk/scp/heat-sealers/heavy-duty-heat-sealer-accessories/
# Using cached data from kite_packaging_data/heavy-duty-heat-sealer-accessories.html
# Processing sub category 116/268: https://www.kitepackaging.co.uk/scp/papers/tissue-paper/
# Fetching data from https://www.kitepackaging.co.uk/scp/papers/tissue-paper/
# Using cached data from kite_packaging_data/tissue-paper.html
# Processing sub category 117/268: https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-films/
# Fetching data from https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-films/
# Using cached data from kite_packaging_data/stretch-films.html
# Processing sub category 118/268: https://www.kitepackaging.co.uk/scp/environmental-products/the-plastic-packaging-tax/
# Fetching data from https://www.kitepackaging.co.uk/scp/environmental-products/the-plastic-packaging-tax/
# Using cached data from kite_packaging_data/the-plastic-packaging-tax.html
# Processing sub category 119/272: https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-films/
# URL https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-films/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-films/, skipping...
# Processing sub category 120/272: https://www.kitepackaging.co.uk/scp/environmental-products/the-plastic-packaging-tax/
# URL https://www.kitepackaging.co.uk/scp/environmental-products/the-plastic-packaging-tax/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/environmental-products/the-plastic-packaging-tax/, skipping...
# Processing sub category 121/272: https://www.kitepackaging.co.uk/scp/environmental-products/reduce/
# Fetching data from https://www.kitepackaging.co.uk/scp/environmental-products/reduce/
# Using cached data from kite_packaging_data/reduce.html
# Processing sub category 122/273: https://www.kitepackaging.co.uk/scp/strapping/strapping-machines/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping/strapping-machines/
# Using cached data from kite_packaging_data/strapping-machines.html
# Processing sub category 123/273: https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-stackers/
# Fetching data from https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-stackers/
# Using cached data from kite_packaging_data/pallet-stackers.html
# Processing sub category 124/273: https://www.kitepackaging.co.uk/scp/strapping/polypropylene-strapping/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping/polypropylene-strapping/
# Using cached data from kite_packaging_data/polypropylene-strapping.html
# Processing sub category 125/277: https://www.kitepackaging.co.uk/scp/strapping/strapping-machines/
# URL https://www.kitepackaging.co.uk/scp/strapping/strapping-machines/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/strapping/strapping-machines/, skipping...
# Processing sub category 126/277: https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-stackers/
# URL https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-stackers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-stackers/, skipping...
# Processing sub category 127/277: https://www.kitepackaging.co.uk/scp/strapping/polypropylene-strapping/
# URL https://www.kitepackaging.co.uk/scp/strapping/polypropylene-strapping/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/strapping/polypropylene-strapping/, skipping...
# Processing sub category 128/277: https://www.kitepackaging.co.uk/scp/papers/vci-paper/
# Fetching data from https://www.kitepackaging.co.uk/scp/papers/vci-paper/
# Using cached data from kite_packaging_data/vci-paper.html
# Processing sub category 129/277: https://www.kitepackaging.co.uk/mcp/bottle-packaging/
# Fetching data from https://www.kitepackaging.co.uk/mcp/bottle-packaging/
# Using cached data from kite_packaging_data/bottle-packaging.html
# Processing sub category 130/277: https://www.kitepackaging.co.uk/scp/mailing-bags/weather-mailers/
# Fetching data from https://www.kitepackaging.co.uk/scp/mailing-bags/weather-mailers/
# Using cached data from kite_packaging_data/weather-mailers.html
# Processing sub category 131/277: https://www.kitepackaging.co.uk/scp/food-packaging/mix-and-match-order-of-takeaway-packaging/
# Fetching data from https://www.kitepackaging.co.uk/scp/food-packaging/mix-and-match-order-of-takeaway-packaging/
# Using cached data from kite_packaging_data/mix-and-match-order-of-takeaway-packaging.html
# Processing sub category 132/277: https://www.kitepackaging.co.uk/scp/postal-envelopes/business-envelopes/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-envelopes/business-envelopes/
# Using cached data from kite_packaging_data/business-envelopes.html
# Processing sub category 133/277: https://www.kitepackaging.co.uk/scp/food-packaging/greaseproof-paper-bags-and-sheets/
# Fetching data from https://www.kitepackaging.co.uk/scp/food-packaging/greaseproof-paper-bags-and-sheets/
# Using cached data from kite_packaging_data/greaseproof-paper-bags-and-sheets.html
# Processing sub category 134/277: https://www.kitepackaging.co.uk/scp/postal-envelopes/all-board-and-board-backed-envelopes/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-envelopes/all-board-and-board-backed-envelopes/
# Using cached data from kite_packaging_data/all-board-and-board-backed-envelopes.html
# Processing sub category 135/277: https://www.kitepackaging.co.uk/scp/packroom-equipment/conveyors/
# Fetching data from https://www.kitepackaging.co.uk/scp/packroom-equipment/conveyors/
# Using cached data from kite_packaging_data/conveyors.html
# Processing sub category 136/277: https://www.kitepackaging.co.uk/scp/heat-sealers/basic-heat-sealer/
# Fetching data from https://www.kitepackaging.co.uk/scp/heat-sealers/basic-heat-sealer/
# Using cached data from kite_packaging_data/basic-heat-sealer.html
# Processing sub category 137/277: https://www.kitepackaging.co.uk/mcp/papers/
# URL https://www.kitepackaging.co.uk/mcp/papers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/papers/, skipping...
# Processing sub category 138/277: https://www.kitepackaging.co.uk/scp/packroom-equipment/heat-shrink-and-vacuum-equipment/
# Fetching data from https://www.kitepackaging.co.uk/scp/packroom-equipment/heat-shrink-and-vacuum-equipment/
# Using cached data from kite_packaging_data/heat-shrink-and-vacuum-equipment.html
# Processing sub category 139/280: https://www.kitepackaging.co.uk/scp/heat-sealers/basic-heat-sealer/
# URL https://www.kitepackaging.co.uk/scp/heat-sealers/basic-heat-sealer/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/heat-sealers/basic-heat-sealer/, skipping...
# Processing sub category 140/280: https://www.kitepackaging.co.uk/mcp/papers/
# URL https://www.kitepackaging.co.uk/mcp/papers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/papers/, skipping...
# Processing sub category 141/280: https://www.kitepackaging.co.uk/scp/packroom-equipment/heat-shrink-and-vacuum-equipment/
# URL https://www.kitepackaging.co.uk/scp/packroom-equipment/heat-shrink-and-vacuum-equipment/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/packroom-equipment/heat-shrink-and-vacuum-equipment/, skipping...
# Processing sub category 142/280: https://www.kitepackaging.co.uk/scp/postal-envelopes/metallic-bubble-envelopes/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-envelopes/metallic-bubble-envelopes/
# Using cached data from kite_packaging_data/metallic-bubble-envelopes.html
# Processing sub category 143/280: https://www.kitepackaging.co.uk/scp/air-bags-and-cushions/air-shock-bottle-packs/
# Fetching data from https://www.kitepackaging.co.uk/scp/air-bags-and-cushions/air-shock-bottle-packs/
# Using cached data from kite_packaging_data/air-shock-bottle-packs.html
# Processing sub category 144/280: https://www.kitepackaging.co.uk/scp/papers/premium-pure-kraft-paper-rolls/
# Fetching data from https://www.kitepackaging.co.uk/scp/papers/premium-pure-kraft-paper-rolls/
# Using cached data from kite_packaging_data/premium-pure-kraft-paper-rolls.html
# Processing sub category 145/280: https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-safe-machine/
# Fetching data from https://www.kitepackaging.co.uk/scp/pallet-wrap/stretch-safe-machine/
# Using cached data from kite_packaging_data/stretch-safe-machine.html
# Processing sub category 146/280: https://www.kitepackaging.co.uk/scp/tapes/gummed-tapes/
# Fetching data from https://www.kitepackaging.co.uk/scp/tapes/gummed-tapes/
# Using cached data from kite_packaging_data/gummed-tapes.html
# Processing sub category 147/280: https://www.kitepackaging.co.uk/scp/printed-tape/standard-printed-tapes/
# Fetching data from https://www.kitepackaging.co.uk/scp/printed-tape/standard-printed-tapes/
# Using cached data from kite_packaging_data/standard-printed-tapes.html
# Processing sub category 148/280: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/corrugated-paper-rolls/
# Fetching data from https://www.kitepackaging.co.uk/scp/protection-and-wrapping/corrugated-paper-rolls/
# Using cached data from kite_packaging_data/corrugated-paper-rolls.html
# Processing sub category 149/280: https://www.kitepackaging.co.uk/scp/food-packaging/plastic-pots/
# Fetching data from https://www.kitepackaging.co.uk/scp/food-packaging/plastic-pots/
# Using cached data from kite_packaging_data/plastic-pots.html
# Processing sub category 150/280: https://www.kitepackaging.co.uk/scp/packroom-equipment/warehouse-gloves/
# Fetching data from https://www.kitepackaging.co.uk/scp/packroom-equipment/warehouse-gloves/
# Using cached data from kite_packaging_data/warehouse-gloves.html
# Processing sub category 151/280: https://www.kitepackaging.co.uk/scp/furniture-bags/washing-machine-bubble-wrap-covers/
# Fetching data from https://www.kitepackaging.co.uk/scp/furniture-bags/washing-machine-bubble-wrap-covers/
# Using cached data from kite_packaging_data/washing-machine-bubble-wrap-covers.html
# Processing sub category 152/280: https://www.kitepackaging.co.uk/scp/heat-shrink-wrap/pallet-shrink-film-systems/
# Fetching data from https://www.kitepackaging.co.uk/scp/heat-shrink-wrap/pallet-shrink-film-systems/
# Using cached data from kite_packaging_data/pallet-shrink-film-systems.html
# Processing sub category 153/280: https://www.kitepackaging.co.uk/mcp/glue-guns-and-sticks/
# Fetching data from https://www.kitepackaging.co.uk/mcp/glue-guns-and-sticks/
# Using cached data from kite_packaging_data/glue-guns-and-sticks.html
# Processing sub category 154/282: https://www.kitepackaging.co.uk/scp/bubble-wrap/small-bubble-wrap/
# Fetching data from https://www.kitepackaging.co.uk/scp/bubble-wrap/small-bubble-wrap/
# Using cached data from kite_packaging_data/small-bubble-wrap.html
# Processing sub category 155/282: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/vermiculite-loose-fill/
# Fetching data from https://www.kitepackaging.co.uk/scp/protection-and-wrapping/vermiculite-loose-fill/
# Using cached data from kite_packaging_data/vermiculite-loose-fill.html
# Processing sub category 156/282: https://www.kitepackaging.co.uk/scp/heat-sealers/impulse-heat-sealers/
# Fetching data from https://www.kitepackaging.co.uk/scp/heat-sealers/impulse-heat-sealers/
# Using cached data from kite_packaging_data/impulse-heat-sealers.html
# Processing sub category 157/282: https://www.kitepackaging.co.uk/scp/strapping/seals-for-strapping/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping/seals-for-strapping/
# Using cached data from kite_packaging_data/seals-for-strapping.html
# Processing sub category 158/282: https://www.kitepackaging.co.uk/scp/plastic-boxes-and-pallets/attached-lid-containers/
# Fetching data from https://www.kitepackaging.co.uk/scp/plastic-boxes-and-pallets/attached-lid-containers/
# Using cached data from kite_packaging_data/attached-lid-containers.html
# Processing sub category 159/282: https://www.kitepackaging.co.uk/mcp/staples/
# Fetching data from https://www.kitepackaging.co.uk/mcp/staples/
# Using cached data from kite_packaging_data/staples.html
# Processing sub category 160/285: https://www.kitepackaging.co.uk/mcp/staples/
# URL https://www.kitepackaging.co.uk/mcp/staples/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/staples/, skipping...
# Processing sub category 161/285: https://www.kitepackaging.co.uk/scp/staples/carton-staplers-and-box-staplers/
# Fetching data from https://www.kitepackaging.co.uk/scp/staples/carton-staplers-and-box-staplers/
# Using cached data from kite_packaging_data/carton-staplers-and-box-staplers.html
# Processing sub category 162/285: https://www.kitepackaging.co.uk/scp/layer-pads-and-sheets/correx-sheets/
# Fetching data from https://www.kitepackaging.co.uk/scp/layer-pads-and-sheets/correx-sheets/
# Using cached data from kite_packaging_data/correx-sheets.html
# Processing sub category 163/285: https://www.kitepackaging.co.uk/scp/postal-envelopes/jiffy-padded-bag/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-envelopes/jiffy-padded-bag/
# Using cached data from kite_packaging_data/jiffy-padded-bag.html
# Processing sub category 164/285: https://www.kitepackaging.co.uk/scp/postal-envelopes/kite-mailers/
# Fetching data from https://www.kitepackaging.co.uk/scp/postal-envelopes/kite-mailers/
# Using cached data from kite_packaging_data/kite-mailers.html
# Processing sub category 165/285: https://www.kitepackaging.co.uk/scp/vacuum-packaging/standard-vacuum-sealers/
# Fetching data from https://www.kitepackaging.co.uk/scp/vacuum-packaging/standard-vacuum-sealers/
# Using cached data from kite_packaging_data/standard-vacuum-sealers.html
# Processing sub category 166/285: https://www.kitepackaging.co.uk/scp/resealable-grip-seal-bags/heavy-duty-grip-seal-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/resealable-grip-seal-bags/heavy-duty-grip-seal-bags/
# Using cached data from kite_packaging_data/heavy-duty-grip-seal-bags.html
# Processing sub category 167/285: https://www.kitepackaging.co.uk/scp/mailing-bags/returnable-paper-mailing-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/mailing-bags/returnable-paper-mailing-bags/
# Using cached data from kite_packaging_data/returnable-paper-mailing-bags.html
# Processing sub category 168/285: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/shredding-machines/
# Fetching data from https://www.kitepackaging.co.uk/scp/protection-and-wrapping/shredding-machines/
# Using cached data from kite_packaging_data/shredding-machines.html
# Processing sub category 169/285: https://www.kitepackaging.co.uk/scp/paper-bags/paper-carrier-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/paper-bags/paper-carrier-bags/
# Using cached data from kite_packaging_data/paper-carrier-bags.html
# Processing sub category 170/285: https://www.kitepackaging.co.uk/printedstandard/printed-envelopes/
# Fetching data from https://www.kitepackaging.co.uk/printedstandard/printed-envelopes/
# Using cached data from kite_packaging_data/printed-envelopes.html
# Processing sub category 171/285: https://www.kitepackaging.co.uk/scp/paper-bags/brown-paper-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/paper-bags/brown-paper-bags/
# Using cached data from kite_packaging_data/brown-paper-bags.html
# Processing sub category 172/285: https://www.kitepackaging.co.uk/scp/bubble-wrap/large-bubble-wrap/
# Fetching data from https://www.kitepackaging.co.uk/scp/bubble-wrap/large-bubble-wrap/
# Using cached data from kite_packaging_data/large-bubble-wrap.html
# Processing sub category 173/285: https://www.kitepackaging.co.uk/scp/polythene-bags/oversized-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/polythene-bags/oversized-bags/
# Using cached data from kite_packaging_data/oversized-bags.html
# Processing sub category 174/285: https://www.kitepackaging.co.uk/scp/glue-guns-and-sticks/glue-guns/
# Fetching data from https://www.kitepackaging.co.uk/scp/glue-guns-and-sticks/glue-guns/
# Using cached data from kite_packaging_data/glue-guns.html
# Processing sub category 175/285: https://www.kitepackaging.co.uk/mcp/corner-and-edge-protection/
# Fetching data from https://www.kitepackaging.co.uk/mcp/corner-and-edge-protection/
# Using cached data from kite_packaging_data/corner-and-edge-protection.html
# Processing sub category 176/294: https://www.kitepackaging.co.uk/scp/polythene-bags/oversized-bags/
# URL https://www.kitepackaging.co.uk/scp/polythene-bags/oversized-bags/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/polythene-bags/oversized-bags/, skipping...
# Processing sub category 177/294: https://www.kitepackaging.co.uk/scp/glue-guns-and-sticks/glue-guns/
# URL https://www.kitepackaging.co.uk/scp/glue-guns-and-sticks/glue-guns/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/glue-guns-and-sticks/glue-guns/, skipping...
# Processing sub category 178/294: https://www.kitepackaging.co.uk/mcp/corner-and-edge-protection/
# URL https://www.kitepackaging.co.uk/mcp/corner-and-edge-protection/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/corner-and-edge-protection/, skipping...
# Processing sub category 179/294: https://www.kitepackaging.co.uk/scp/food-packaging/paper-coffee-cups/
# Fetching data from https://www.kitepackaging.co.uk/scp/food-packaging/paper-coffee-cups/
# Using cached data from kite_packaging_data/paper-coffee-cups.html
# Processing sub category 180/294: https://www.kitepackaging.co.uk/scp/heat-shrink-wrap/heat-shrink-film-systems/
# Fetching data from https://www.kitepackaging.co.uk/scp/heat-shrink-wrap/heat-shrink-film-systems/
# Using cached data from kite_packaging_data/heat-shrink-film-systems.html
# ...
# URL https://www.kitepackaging.co.uk/scp/environmental-products/replace/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/environmental-products/replace/, skipping...
# Processing sub category 261/310: https://www.kitepackaging.co.uk/scp/heat-shrink-wrap/pallet-shrink-film-systems-spare-parts/
# Fetching data from https://www.kitepackaging.co.uk/scp/heat-shrink-wrap/pallet-shrink-film-systems-spare-parts/
# Using cached data from kite_packaging_data/pallet-shrink-film-systems-spare-parts.html
# Processing sub category 262/310: https://www.kitepackaging.co.uk/scp/labels/thermal-labels/
# URL https://www.kitepackaging.co.uk/scp/labels/thermal-labels/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/labels/thermal-labels/, skipping...
# Processing sub category 263/310: https://www.kitepackaging.co.uk/mcp/heat-shrink-machines-and-equipment/
# URL https://www.kitepackaging.co.uk/mcp/heat-shrink-machines-and-equipment/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/heat-shrink-machines-and-equipment/, skipping...
# Processing sub category 264/310: https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-wrap-bags/
# URL https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-wrap-bags/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-wrap-bags/, skipping...
# Processing sub category 265/310: https://www.kitepackaging.co.uk/scp/tapes/tape-dispensers/
# URL https://www.kitepackaging.co.uk/scp/tapes/tape-dispensers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/tapes/tape-dispensers/, skipping...
# Processing sub category 266/310: https://www.kitepackaging.co.uk/mcp/envelopes/
# URL https://www.kitepackaging.co.uk/mcp/envelopes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/envelopes/, skipping...
# Processing sub category 267/310: https://www.kitepackaging.co.uk/scp/corner-and-edge-protection/round-cut-corner-protection/
# Fetching data from https://www.kitepackaging.co.uk/scp/corner-and-edge-protection/round-cut-corner-protection/
# Using cached data from kite_packaging_data/round-cut-corner-protection.html
# Processing sub category 268/310: https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-stackers/
# URL https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-stackers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/packroom-equipment/pallet-stackers/, skipping...
# Processing sub category 269/310: https://www.kitepackaging.co.uk/mcp/bottle-packaging/
# URL https://www.kitepackaging.co.uk/mcp/bottle-packaging/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/bottle-packaging/, skipping...
# Processing sub category 270/310: https://www.kitepackaging.co.uk/scp/postal-envelopes/business-envelopes/
# URL https://www.kitepackaging.co.uk/scp/postal-envelopes/business-envelopes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/postal-envelopes/business-envelopes/, skipping...
# Processing sub category 271/310: https://www.kitepackaging.co.uk/scp/food-packaging/greaseproof-paper-bags-and-sheets/
# URL https://www.kitepackaging.co.uk/scp/food-packaging/greaseproof-paper-bags-and-sheets/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/food-packaging/greaseproof-paper-bags-and-sheets/, skipping...
# Processing sub category 272/310: https://www.kitepackaging.co.uk/scp/papers/paper-void-fill-dispensers/
# Fetching data from https://www.kitepackaging.co.uk/scp/papers/paper-void-fill-dispensers/
# Using cached data from kite_packaging_data/paper-void-fill-dispensers.html
# Processing sub category 273/310: https://www.kitepackaging.co.uk/scp/papers/premium-pure-kraft-paper-rolls/
# URL https://www.kitepackaging.co.uk/scp/papers/premium-pure-kraft-paper-rolls/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/papers/premium-pure-kraft-paper-rolls/, skipping...
# Processing sub category 274/310: https://www.kitepackaging.co.uk/scp/tapes/gummed-tapes/
# URL https://www.kitepackaging.co.uk/scp/tapes/gummed-tapes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/tapes/gummed-tapes/, skipping...
# Processing sub category 275/310: https://www.kitepackaging.co.uk/scp/printed-tape/standard-printed-tapes/
# URL https://www.kitepackaging.co.uk/scp/printed-tape/standard-printed-tapes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/printed-tape/standard-printed-tapes/, skipping...
# Processing sub category 276/310: https://www.kitepackaging.co.uk/scp/furniture-bags/washing-machine-bubble-wrap-covers/
# URL https://www.kitepackaging.co.uk/scp/furniture-bags/washing-machine-bubble-wrap-covers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/furniture-bags/washing-machine-bubble-wrap-covers/, skipping...
# Processing sub category 277/310: https://www.kitepackaging.co.uk/scp/packroom-equipment/warehouse-gloves/
# URL https://www.kitepackaging.co.uk/scp/packroom-equipment/warehouse-gloves/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/packroom-equipment/warehouse-gloves/, skipping...
# Processing sub category 278/310: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/vermiculite-loose-fill/
# URL https://www.kitepackaging.co.uk/scp/protection-and-wrapping/vermiculite-loose-fill/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/protection-and-wrapping/vermiculite-loose-fill/, skipping...
# Processing sub category 279/310: https://www.kitepackaging.co.uk/scp/strapping/seals-for-strapping/
# URL https://www.kitepackaging.co.uk/scp/strapping/seals-for-strapping/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/strapping/seals-for-strapping/, skipping...
# Processing sub category 280/310: https://www.kitepackaging.co.uk/mcp/staples/
# URL https://www.kitepackaging.co.uk/mcp/staples/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/mcp/staples/, skipping...
# Processing sub category 281/310: https://www.kitepackaging.co.uk/scp/mailing-bags/grey-mailing-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/mailing-bags/grey-mailing-bags/
# Using cached data from kite_packaging_data/grey-mailing-bags.html
# Processing sub category 282/310: https://www.kitepackaging.co.uk/scp/postal-envelopes/jiffy-padded-bag/
# URL https://www.kitepackaging.co.uk/scp/postal-envelopes/jiffy-padded-bag/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/postal-envelopes/jiffy-padded-bag/, skipping...
# Processing sub category 283/310: https://www.kitepackaging.co.uk/scp/postal-envelopes/kite-mailers/
# URL https://www.kitepackaging.co.uk/scp/postal-envelopes/kite-mailers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/postal-envelopes/kite-mailers/, skipping...
# Processing sub category 284/310: https://www.kitepackaging.co.uk/scp/mailing-bags/heavy-duty-co-extruded-mailing-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/mailing-bags/heavy-duty-co-extruded-mailing-bags/
# Using cached data from kite_packaging_data/heavy-duty-co-extruded-mailing-bags.html
# Processing sub category 285/310: https://www.kitepackaging.co.uk/scp/heat-shrink-machines-and-equipment/shrink-seal-hood-machine/
# URL https://www.kitepackaging.co.uk/scp/heat-shrink-machines-and-equipment/shrink-seal-hood-machine/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/heat-shrink-machines-and-equipment/shrink-seal-hood-machine/, skipping...
# Processing sub category 286/310: https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/timber-cases-and-wooden-crates/
# URL https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/timber-cases-and-wooden-crates/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/timber-cases-and-wooden-crates/, skipping...
# Processing sub category 287/310: https://www.kitepackaging.co.uk/scp/strapping-and-ties/rubber-bands/
# URL https://www.kitepackaging.co.uk/scp/strapping-and-ties/rubber-bands/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/strapping-and-ties/rubber-bands/, skipping...
# Processing sub category 288/310: https://www.kitepackaging.co.uk/scp/gift-packaging/zigzag-4mm-shredded-paper/
# URL https://www.kitepackaging.co.uk/scp/gift-packaging/zigzag-4mm-shredded-paper/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/gift-packaging/zigzag-4mm-shredded-paper/, skipping...
# Processing sub category 289/310: https://www.kitepackaging.co.uk/scp/packroom-equipment/waste-compactors-and-cardboard-balers/
# URL https://www.kitepackaging.co.uk/scp/packroom-equipment/waste-compactors-and-cardboard-balers/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/packroom-equipment/waste-compactors-and-cardboard-balers/, skipping...
# Processing sub category 290/310: https://www.kitepackaging.co.uk/scp/paper-bags/wine-bottle-bags/
# URL https://www.kitepackaging.co.uk/scp/paper-bags/wine-bottle-bags/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/paper-bags/wine-bottle-bags/, skipping...
# Processing sub category 291/310: https://www.kitepackaging.co.uk/scp/sealing-and-security/knives/
# URL https://www.kitepackaging.co.uk/scp/sealing-and-security/knives/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/sealing-and-security/knives/, skipping...
# Processing sub category 292/310: https://www.kitepackaging.co.uk/scp/papers/kraft-union-paper/
# URL https://www.kitepackaging.co.uk/scp/papers/kraft-union-paper/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/papers/kraft-union-paper/, skipping...
# Processing sub category 293/310: https://www.kitepackaging.co.uk/scp/strapping/steel-strapping-reels/
# URL https://www.kitepackaging.co.uk/scp/strapping/steel-strapping-reels/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/strapping/steel-strapping-reels/, skipping...
# Processing sub category 294/310: https://www.kitepackaging.co.uk/scp/food-packaging/takeaway-boxes/
# URL https://www.kitepackaging.co.uk/scp/food-packaging/takeaway-boxes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/food-packaging/takeaway-boxes/, skipping...
# Processing sub category 295/310: https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-bags/
# URL https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-bags/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/bubble-wrap/bubble-bags/, skipping...
# Processing sub category 296/310: https://www.kitepackaging.co.uk/scp/packroom-equipment/case-erectors/
# URL https://www.kitepackaging.co.uk/scp/packroom-equipment/case-erectors/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/packroom-equipment/case-erectors/, skipping...
# Processing sub category 297/310: https://www.kitepackaging.co.uk/scp/postal-boxes/large-letter-postal-boxes/
# URL https://www.kitepackaging.co.uk/scp/postal-boxes/large-letter-postal-boxes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/postal-boxes/large-letter-postal-boxes/, skipping...
# Processing sub category 298/310: https://www.kitepackaging.co.uk/scp/air-bags-and-cushions/air-shock-pouches/
# Fetching data from https://www.kitepackaging.co.uk/scp/air-bags-and-cushions/air-shock-pouches/
# Using cached data from kite_packaging_data/air-shock-pouches.html
# Processing sub category 299/312: https://www.kitepackaging.co.uk/scp/postal-boxes/large-letter-postal-boxes/
# URL https://www.kitepackaging.co.uk/scp/postal-boxes/large-letter-postal-boxes/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/postal-boxes/large-letter-postal-boxes/, skipping...
# Processing sub category 300/312: https://www.kitepackaging.co.uk/scp/air-bags-and-cushions/air-shock-pouches/
# URL https://www.kitepackaging.co.uk/scp/air-bags-and-cushions/air-shock-pouches/ has already been processed.
# Failed to fetch data for https://www.kitepackaging.co.uk/scp/air-bags-and-cushions/air-shock-pouches/, skipping...
# Processing sub category 301/312: https://www.kitepackaging.co.uk/scp/air-bags-and-cushions/air-cushions/
# Fetching data from https://www.kitepackaging.co.uk/scp/air-bags-and-cushions/air-cushions/
# Using cached data from kite_packaging_data/air-cushions.html
# Processing sub category 302/312: https://www.kitepackaging.co.uk/scp/heat-sealers/hand-held-heat-sealers/
# Fetching data from https://www.kitepackaging.co.uk/scp/heat-sealers/hand-held-heat-sealers/
# Using cached data from kite_packaging_data/hand-held-heat-sealers.html
# Processing sub category 303/312: https://www.kitepackaging.co.uk/scp/boxes/corrugated-storage-bins/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/corrugated-storage-bins/
# Using cached data from kite_packaging_data/corrugated-storage-bins.html
# Processing sub category 304/312: https://www.kitepackaging.co.uk/scp/polythene-bags/standard-polythene-bags/
# Fetching data from https://www.kitepackaging.co.uk/scp/polythene-bags/standard-polythene-bags/
# Using cached data from kite_packaging_data/standard-polythene-bags.html
# Processing sub category 305/312: https://www.kitepackaging.co.uk/scp/packaging-regulations/ppt-faqs/
# Fetching data from https://www.kitepackaging.co.uk/scp/packaging-regulations/ppt-faqs/
# Using cached data from kite_packaging_data/ppt-faqs.html
# Error processing https://www.kitepackaging.co.uk/scp/packaging-regulations/ppt-faqs/: No script tag with id 'ang-data-source' found in the HTML.
# Processing sub category 306/312: https://www.kitepackaging.co.uk/scp/boxes/pallet-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/boxes/pallet-boxes/
# Using cached data from kite_packaging_data/pallet-boxes.html
# Processing sub category 307/312: https://www.kitepackaging.co.uk/scp/protection-and-wrapping/wood-wool/
# Fetching data from https://www.kitepackaging.co.uk/scp/protection-and-wrapping/wood-wool/
# Using cached data from kite_packaging_data/wood-wool.html
# Processing sub category 308/312: https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/handle-with-care-boxes/
# Fetching data from https://www.kitepackaging.co.uk/scp/heavy-duty-cardboard-boxes/handle-with-care-boxes/
# Using cached data from kite_packaging_data/handle-with-care-boxes.html
# Processing sub category 309/312: https://www.kitepackaging.co.uk/scp/corner-and-edge-protection/foam-shock-absorption-protection/
# Fetching data from https://www.kitepackaging.co.uk/scp/corner-and-edge-protection/foam-shock-absorption-protection/
# Using cached data from kite_packaging_data/foam-shock-absorption-protection.html
# Processing sub category 310/312: https://www.kitepackaging.co.uk/scp/food-packaging/cutlery/
# Fetching data from https://www.kitepackaging.co.uk/scp/food-packaging/cutlery/
# Using cached data from kite_packaging_data/cutlery.html
# Processing sub category 311/312: https://www.kitepackaging.co.uk/scp/strapping/steel-strapping-seals/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping/steel-strapping-seals/
# Using cached data from kite_packaging_data/steel-strapping-seals.html
# Processing sub category 312/312: https://www.kitepackaging.co.uk/scp/strapping/polypropylene-strapping-reels/
# Fetching data from https://www.kitepackaging.co.uk/scp/strapping/polypropylene-strapping-reels/
# Using cached data from kite_packaging_data/polypropylene-strapping-reels.html

# %%
len(PROCESSED_URLS)
# Out:
# 239

# %%
master_prod_df.shape
# Out:
# (1244, 129)

# %%
master_prod_df.to_excel("kite_packaging_data.xlsx", index=False)

# %%
specs_dict
# Out:
# {'Box type': 'Standard',
#  'Closure': 'Standard Box (seal with tape)',
#  'Colour': 'Brown',
#  'Material': 'Cardboard',
#  'PackagingRegsMaterial': 'Paper',
#  'Strength': 'Double Wall'}
